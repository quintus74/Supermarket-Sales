# %%
import pandas as pd
df = pd.read_csv('Supermarket Sales.csv')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#        Payment
# 0      Ewallet
# 1         Cash
# 2  Credit card
# 3      Ewallet
# 4      Ewallet

# %%
to_drop = ['Invoice ID',
          'City',
          'Payment']
df.drop(to_drop, inplace=True, axis=1)

# %%
df.head()
# Out:
#   Branch Customer type  Gender            Product line  Unit price  Quantity  \
# 0      A        Member  Female       Health and beauty       74.69         7
# 1      C        Normal  Female  Electronic accessories       15.28         5
# 2      A        Normal    Male      Home and lifestyle       46.33         7
# 3      A        Member    Male       Health and beauty       58.22         8
# 4      A        Normal    Male       Sports and travel       86.31         7
#
#     Tax 5%     Total       Date
# 0  26.1415  548.9715   1/5/2019
# 1   3.8200   80.2200   3/8/2019
# 2  16.2155  340.5255   3/3/2019
# 3  23.2880  489.0480  1/27/2019
# 4  30.2085  634.3785   2/8/2019

# %%
df.sort_values("Date")
# Out:
#     Branch Customer type  Gender            Product line  Unit price  \
# 496      C        Normal  Female  Electronic accessories       63.22
# 484      C        Member  Female       Sports and travel       36.98
# 567      A        Normal  Female     Fashion accessories       65.74
# 523      C        Normal    Male       Health and beauty       62.87
# 970      B        Member  Female      Food and beverages       84.63
# ..     ...           ...     ...                     ...         ...
# 393      A        Member  Female       Sports and travel       52.26
# 73       C        Normal  Female  Electronic accessories       75.91
# 433      B        Normal    Male     Fashion accessories       95.54
# 585      A        Normal    Male       Health and beauty       51.71
# 84       C        Member    Male       Sports and travel       48.91
#
#      Quantity   Tax 5%     Total      Date
# 496         2   6.3220  132.7620  1/1/2019
# 484        10  18.4900  388.2900  1/1/2019
# ...

# %%
df.sort_values("Product line")
# Out:
#     Branch Customer type  Gender            Product line  Unit price  \
# 202      C        Normal    Male  Electronic accessories       61.41
# 303      A        Normal  Female  Electronic accessories       51.19
# 451      B        Normal    Male  Electronic accessories       22.01
# 891      B        Normal  Female  Electronic accessories       57.91
# 454      A        Member    Male  Electronic accessories       20.77
# ..     ...           ...     ...                     ...         ...
# 169      A        Member    Male       Sports and travel       69.52
# 684      B        Member  Female       Sports and travel       23.08
# 873      A        Member    Male       Sports and travel       89.06
# 131      A        Member  Female       Sports and travel       92.13
# 499      A        Member  Female       Sports and travel       51.52
#
#      Quantity   Tax 5%     Total       Date
# 202         7  21.4935  451.3635  1/14/2019
# 303         4  10.2380  214.9980  3/18/2019
# ...

# %%
df.sort_values("Customer type")
df.sort_values("Gender")
df.sort_values("Product line")
df.sort_values("Quantity")
df.sort_values("Date")
# Out:
#     Branch Customer type  Gender            Product line  Unit price  \
# 496      C        Normal  Female  Electronic accessories       63.22
# 484      C        Member  Female       Sports and travel       36.98
# 567      A        Normal  Female     Fashion accessories       65.74
# 523      C        Normal    Male       Health and beauty       62.87
# 970      B        Member  Female      Food and beverages       84.63
# ..     ...           ...     ...                     ...         ...
# 393      A        Member  Female       Sports and travel       52.26
# 73       C        Normal  Female  Electronic accessories       75.91
# 433      B        Normal    Male     Fashion accessories       95.54
# 585      A        Normal    Male       Health and beauty       51.71
# 84       C        Member    Male       Sports and travel       48.91
#
#      Quantity   Tax 5%     Total      Date
# 496         2   6.3220  132.7620  1/1/2019
# 484        10  18.4900  388.2900  1/1/2019
# ...
